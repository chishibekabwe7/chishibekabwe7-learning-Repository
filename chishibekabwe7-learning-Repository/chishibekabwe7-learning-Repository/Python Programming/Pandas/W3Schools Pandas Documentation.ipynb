# %%
#!/usr/bin/env python3

import pandas as pd
 
a = [1,2,3]

#Labels and Series
myvar = pd.Series(a)
print(myvar)
print(myvar[0])
myvar = pd.Series(a, index = ["x","y","z"])
print(myvar)

# Also valid with Key/value Objects or Dictonaries
calories = {"day1":420, "day2":380, "day3": 390}
myvar = pd.Series(calories, index = [1,2,3])
print(calories)

#Data Frames
column =  ["Ricky","EJ","Gina"]
title_column = {"name":column,
                "height":[1.67,1.9,0.25],
                "weight":[54,100,1]}
data = pd.DataFrame(title_column, index = ["#1","#2","#3"])
print(data)

#Select Values from Dataframe
select_column = data["weight"]
select_row = data["weight"][0]
select_row = data.iloc[1]["weight"]
print(select_column)
print(select_row)

# Reading CSV Files
#df = pd.read_csv('./Data Cleaning Samples/data.csv')
df = pd.read_csv('./Data Cleaning Samples/annual-enterprise-survey-2021-financial-year-provisional-size-bands-csv.csv')

# #Outputs the last 5 Rows
# print(df)

# #Outputs the First 5 Rows
# print(df.head())

#Outputing the Entire Row
df_string = df.to_string()
print(df_string)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64
# 1
# x    1
# y    2
# z    3
# dtype: int64
# {'day1': 420, 'day2': 380, 'day3': 390}
#      name  height  weight
# #1  Ricky    1.67      54
# #2     EJ    1.90     100
# #3   Gina    0.25       1
# #1     54
# #2    100
# #3      1
# Name: weight, dtype: int64
# 100
#        year industry_code_ANZSIC                             industry_name_ANZSIC      rme_size_grp                                         variable    value               unit
# 0      2011                    A                Agriculture, Forestry and Fishing               a_0                                    Activity unit    46134              COUNT
# 1      2011                    A                Agriculture, Forestry and Fishing               a_0                           Rolling mean employees        0              COUNT
# ...

# %%
#!/usr/bin/env python3
import pandas as pd
Data_Frame = pd.read_csv('./Data Cleaning Samples/business-operations-survey-2023-innovation.csv')
print(Data_Frame.to_string())
